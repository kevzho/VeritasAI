# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
tickers_list = ['AAPL', 'WMT', 'IBM', 'MU', 'BA', 'AXP']

# Fetch the data
import yfinance as yf
#just get the close prices of all of the tickers in tickers_list
data = yf.download(tickers_list, start='2021-01-01', end='2022-01-01', interval = '1mo')['Close']

# Print first 12 rows of the data
data.head(12)
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_9428\1221858415.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers_list, start='2021-01-01', end='2022-01-01', interval = '1mo')['Close']
# [*********************100%***********************]  6 of 6 completed
# Ticker            AAPL         AXP          BA         IBM         MU  \
# Date
# 2021-01-01  128.727203  109.572189  194.190002   93.721329  76.446480
# 2021-02-01  118.289352  127.926170  212.009995   93.579681  89.397575
# 2021-03-01  119.335594  133.771133  254.720001  106.256378  86.154915
# 2021-04-01  128.431122  145.471313  234.309998  113.129631  84.064766
# 2021-05-01  121.738930  151.903000  247.020004  114.612755  82.179741
# 2021-06-01  134.031647  156.740982  239.559998  118.191193  83.000160
# 2021-07-01  142.741394  161.768692  226.479996  113.651901  75.772568
# 2021-08-01  148.583725  157.844269  219.500000  113.151993  71.982971
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot all the close prices
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))
#get the percent change using function and get the cumulative product,
#what we did last time and plot it

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Returns", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Cumulative Returns', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %% [markdown]
# Almost **all** stocks increased in price near the end of 2021

# %%
# Read and print the stock tickers that make up S&P500 pulled from Wikipedia
tickers = pd.read_html(
    'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
tickers.head()
# Out:
#   Symbol             Security             GICS Sector  \
# 0    MMM                   3M             Industrials
# 1    AOS          A. O. Smith             Industrials
# 2    ABT  Abbott Laboratories             Health Care
# 3   ABBV               AbbVie             Health Care
# 4    ACN            Accenture  Information Technology
#
#                 GICS Sub-Industry    Headquarters Location  Date added  \
# 0        Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1               Building Products     Milwaukee, Wisconsin  2017-07-26
# 2           Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                   Biotechnology  North Chicago, Illinois  2012-12-31
# 4  IT Consulting & Other Services          Dublin, Ireland  2011-07-06
#
#        CIK      Founded
# 0    66740         1902
# 1    91142         1916
# 2     1800         1888
# 3  1551152  2013 (1888)
# 4  1467373         1989

# %%
data.head()
# Out:
# Ticker            AAPL         AXP          BA         IBM         MU  \
# Date
# 2021-01-01  128.727203  109.572189  194.190002   93.721329  76.446480
# 2021-02-01  118.289352  127.926170  212.009995   93.579681  89.397575
# 2021-03-01  119.335594  133.771133  254.720001  106.256378  86.154915
# 2021-04-01  128.431122  145.471313  234.309998  113.129631  84.064766
# 2021-05-01  121.738930  151.903000  247.020004  114.612755  82.179741
#
# Ticker            WMT
# Date
# 2021-01-01  43.945045
# 2021-02-01  40.638760
# 2021-03-01  42.487404
# 2021-04-01  43.946335
# 2021-05-01  44.612244

# %%
new_table = data.pct_change()
new_table
# Out:
# Ticker          AAPL       AXP        BA       IBM        MU       WMT
# Date
# 2021-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-02-01 -0.081085  0.167506  0.091766 -0.001511  0.169414 -0.075237
# 2021-03-01  0.008845  0.045690  0.201453  0.135464 -0.036272  0.045490
# 2021-04-01  0.076218  0.087464 -0.080127  0.064686 -0.024260  0.034338
# 2021-05-01 -0.052107  0.044213  0.054244  0.013110 -0.022423  0.015153
# 2021-06-01  0.100976  0.031849 -0.030200  0.031222  0.009983 -0.003212
# 2021-07-01  0.064983  0.032077 -0.054600 -0.038406 -0.087079  0.010849
# 2021-08-01  0.040929 -0.024259 -0.030819 -0.004399 -0.050013  0.038934
# 2021-09-01 -0.066640  0.009460  0.002005  0.001350 -0.036906 -0.055416
# 2021-10-01  0.058657  0.037307 -0.058698 -0.099546 -0.025126  0.072034
# 2021-11-01  0.103471 -0.121426 -0.044341 -0.020891  0.215629 -0.058828
# 2021-12-01  0.075796  0.074196  0.017539  0.156649  0.108929  0.028870

# %% [markdown]
# To compound the returns, simply add 1 to each return value and multiply them against each other:

# %%
np.prod(new_table+1)
# Out:
# c:\Users\kevin\anaconda3\envs\myenv\Lib\site-packages\numpy\_core\fromnumeric.py:84: FutureWarning: The behavior of DataFrame.prod with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Ticker
# AAPL    1.353931
# AXP     1.423595
# BA      1.036717
# IBM     1.232832
# MU      1.191775
# WMT     1.042078
# dtype: float64

# %% [markdown]
# ## Annualizing Returns
#
# To annualize a return for a period, you compound the return for as many times as there are periods in a year. For instance, to annualize a monthly return you compund that return 12 times. The formula to annualize a monthly return $R_m$ is:
#
# $$ (1+R_m)^{12} - 1$$
#
# To annualize a quarterly return $R_q$ you would get:
#
# $$ (1+R_q)^{4} - 1$$
#
# And finally, to annualize a daily return $R_d$ you would get:
#
# $$ (1+R_d)^{252} - 1$$
#
# For example, to annualize a 1% monthly, and 4% quarterly and a 0.01% daily return you would do:

# %%
rm = 0.01
rq = 0.04
print(f"Monthly Return {(1+rm)**12 - 1}")
print(f"Quarterly Return {(1+rq)**4 - 1}")
# Out:
# Monthly Return 0.12682503013196977
# Quarterly Return 0.1698585600000002
